# %%
import csv
"""
donnees=[]
with open('donnees_global.csv',newline='') as csvfile:
	reader=csv.reader(csvfile,delimiter=';')
	for row in reader:
		donnees.append(row)
#print(donnees)

mt=[]
for i in range(1,len(donnees)):
	mt.append(donnees[i][2])
#print(mt)

annees=[]
moyennes=[]
somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2014":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2014=somme/nb
#print("Moyenne 2014 =", moyenne_2014)
annees.append(2014)
moyennes.append(moyenne_2014)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2015":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2015=somme/nb
#print("Moyenne 2015 =", moyenne_2015)
annees.append(2015)
moyennes.append(moyenne_2015)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2016":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2016=somme/nb
#print("Moyenne 2016 =", moyenne_2016)
annees.append(2016)
moyennes.append(moyenne_2016)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2017":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2017=somme/nb
#print("Moyenne 2017 =", moyenne_2017)
annees.append(2017)
moyennes.append(moyenne_2017)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2018":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2018=somme/nb
#print("Moyenne 2018 =", moyenne_2018)
annees.append(2018)
moyennes.append(moyenne_2018)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2019":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2019=somme/nb
#print("Moyenne 2019 =", moyenne_2019)
annees.append(2019)
moyennes.append(moyenne_2019)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2020":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2020=somme/nb
#print("Moyenne 2020 =", moyenne_2020)
annees.append(2020)
moyennes.append(moyenne_2020)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2021":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2021=somme/nb
#print("Moyenne 2021 =", moyenne_2021)
annees.append(2021)
moyennes.append(moyenne_2021)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2022":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2022=somme/nb
#print("Moyenne 2022 =", moyenne_2022)
annees.append(2022)
moyennes.append(moyenne_2022)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2023":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2023=somme/nb
#print("Moyenne 2023 =", moyenne_2023)
annees.append(2023)
moyennes.append(moyenne_2023)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2024":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2024=somme/nb
#print("Moyenne 2024 =", moyenne_2024)
annees.append(2024)
moyennes.append(moyenne_2024)

somme=0
nb=0

for i in range(1,len(donnees)):
    if donnees[i][0][:4]=="2025":
        somme+=float(donnees[i][2].replace(",", "."))
        nb+=1
        moyenne_2025=somme/nb
#print("Moyenne 2025 =", moyenne_2025)
annees.append(2025)
moyennes.append(moyenne_2025)

from matplotlib import pyplot as plt

plt.plot(annees, moyennes, marker="o")
plt.ylabel("Émissions moyennes annuelles (Mt)")
plt.xlabel("Année")
plt.title("Évolution des émissions moyennes annuelles de GES liées à la production d'électricité")
plt.xticks(annees)
plt.show()
"""

donnees2=[]
with open('donnees_global_2.csv',newline='') as csvfile:
	reader=csv.reader(csvfile,delimiter=';')
	for row in reader:
		donnees2.append(row)
#print(donnees2)

mt2=[]
for i in range(1,len(donnees2)):
	mt2.append(donnees2[i][2])
#print(mt2)

annees=[]
moyennes=[]
somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2017":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2017=somme/nb
#print("Moyenne 2017 =", moyenne_2017)
annees.append(2017)
moyennes.append(moyenne_2017)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2018":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2018=somme/nb
#print("Moyenne 2018 =", moyenne_2018)
annees.append(2018)
moyennes.append(moyenne_2018)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2019":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2019=somme/nb
#print("Moyenne 2019 =", moyenne_2019)
annees.append(2019)
moyennes.append(moyenne_2019)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2020":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2020=somme/nb
#print("Moyenne 2020 =", moyenne_2020)
annees.append(2020)
moyennes.append(moyenne_2020)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2021":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2021=somme/nb
#print("Moyenne 2021 =", moyenne_2021)
annees.append(2021)
moyennes.append(moyenne_2021)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2022":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2022=somme/nb
#print("Moyenne 2022 =", moyenne_2022)
annees.append(2022)
moyennes.append(moyenne_2022)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2023":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2023=somme/nb
#print("Moyenne 2023 =", moyenne_2023)
annees.append(2023)
moyennes.append(moyenne_2023)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2024":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2024=somme/nb
#print("Moyenne 2024 =", moyenne_2024)
annees.append(2024)
moyennes.append(moyenne_2024)

somme=0
nb=0

for i in range(1,len(donnees2)):
    if donnees2[i][0][:4]=="2025":
        valeur=donnees2[i][2]
        if valeur!= "":
            somme+=float(valeur.replace(",", "."))
            nb+=1
            moyenne_2025=somme/nb
#print("Moyenne 2025 =", moyenne_2025)
annees.append(2025)
moyennes.append(moyenne_2025)

from matplotlib import pyplot as plt

plt.plot(annees, moyennes, marker="o")
plt.ylabel("Émissions moyennes annuelles (Mt)")
plt.xlabel("Année")
plt.title("Évolution des émissions moyennes annuelles de GES liées à la consommation d'électricité")
plt.xticks(annees)
plt.show()
